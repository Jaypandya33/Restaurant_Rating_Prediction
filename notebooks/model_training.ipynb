# %%
import pandas as pd
import numpy as np

# %%
data=pd.read_csv("final_data.csv")

# %%
data
# Out:
#       online_order book_table      rate  votes      location      rest_type  \
# 0              Yes        Yes  4.100000    775  Banashankari  Casual Dining
# 1              Yes         No  4.100000    787  Banashankari  Casual Dining
# 2              Yes         No  3.800000    918  Banashankari         others
# 3               No         No  3.700000     88  Banashankari    Quick Bites
# 4               No         No  3.800000    166  Basavanagudi  Casual Dining
# ...            ...        ...       ...    ...           ...            ...
# 51712           No         No  3.600000     27    Whitefield         others
# 51713           No         No  3.700449      0    Whitefield         others
# 51714           No         No  3.700449      0    Whitefield         others
# 51715           No        Yes  4.300000    236        others         others
# 51716           No         No  3.400000     13        others         others
#
#                          cuisines  cost_for_two_people           type
# 0                          others           800.000000         Buffet
# 1                          others           800.000000         Buffet
# 2                          others           800.000000         Buffet
# 3      South Indian, North Indian           300.000000         Buffet
# 4                          others           600.000000         Buffet
# ...                           ...                  ...            ...
# 51712                      others           416.630112  Pubs and bars
# 51713                      others           600.000000  Pubs and bars
# 51714                      others           416.630112  Pubs and bars
# 51715                      others           416.630112  Pubs and bars
# 51716                      others           416.630112  Pubs and bars
#
# [51717 rows x 9 columns]

# %%
X=data.drop(labels=["rate"],axis=1)

# %%
y=data[["rate"]]

# %%
X
# Out:
#       online_order book_table  votes      location      rest_type  \
# 0              Yes        Yes    775  Banashankari  Casual Dining
# 1              Yes         No    787  Banashankari  Casual Dining
# 2              Yes         No    918  Banashankari         others
# 3               No         No     88  Banashankari    Quick Bites
# 4               No         No    166  Basavanagudi  Casual Dining
# ...            ...        ...    ...           ...            ...
# 51712           No         No     27    Whitefield         others
# 51713           No         No      0    Whitefield         others
# 51714           No         No      0    Whitefield         others
# 51715           No        Yes    236        others         others
# 51716           No         No     13        others         others
#
#                          cuisines  cost_for_two_people           type
# 0                          others           800.000000         Buffet
# 1                          others           800.000000         Buffet
# 2                          others           800.000000         Buffet
# 3      South Indian, North Indian           300.000000         Buffet
# 4                          others           600.000000         Buffet
# ...                           ...                  ...            ...
# 51712                      others           416.630112  Pubs and bars
# 51713                      others           600.000000  Pubs and bars
# 51714                      others           416.630112  Pubs and bars
# 51715                      others           416.630112  Pubs and bars
# 51716                      others           416.630112  Pubs and bars
#
# [51717 rows x 8 columns]

# %%
y
# Out:
#            rate
# 0      4.100000
# 1      4.100000
# 2      3.800000
# 3      3.700000
# 4      3.800000
# ...         ...
# 51712  3.600000
# 51713  3.700449
# 51714  3.700449
# 51715  4.300000
# 51716  3.400000
#
# [51717 rows x 1 columns]

# %% [markdown]
# MODELS

# %%
from sklearn.impute import SimpleImputer ## HAndling Missing Values
from sklearn.preprocessing import StandardScaler # HAndling Feature Scaling
from sklearn.preprocessing import OrdinalEncoder # Ordinal Encoding
from sklearn.preprocessing import OneHotEncoder
## pipelines
from sklearn.pipeline import Pipeline
from sklearn.compose import ColumnTransformer

# %%
# Define which columns should be ordinal-encoded and which should be scaled
categorical_cols = ['online_order', 'book_table', 'location', 'rest_type', 'cuisines', 'type', 'cost_for_two_people']
numerical_cols = ['votes']

# %%
## Numerical Pipeline
num_pipeline=Pipeline(
    steps=[
    ('imputer',SimpleImputer(strategy='median')), #to cheeck empty value
    ('scaler',StandardScaler())    #to perform scaling

    ]

)

# %%
# Categorigal Pipeline
cat_pipeline=Pipeline(
    steps=[
    ('imputer',SimpleImputer(strategy='most_frequent')),   #handling missing value using mode ,not mean.
    ('ordinalencoder',OneHotEncoder(sparse_output=False, handle_unknown='ignore', categories='auto')), #created object for cat_encoding
    ('scaler',StandardScaler())
    ]
)

# %%
preprocessor=ColumnTransformer(
    [
        
        ('num_pipeline',num_pipeline,numerical_cols),
        ('cat_pipeline',cat_pipeline,categorical_cols)
    ]
)

# %%
## Train test split

from sklearn.model_selection import train_test_split

X_train,X_test,y_train,y_test=train_test_split(X,y,test_size=0.30,random_state=30)

# %%
preprocessor.fit_transform(X_train)
# Out:
# array([[-0.12475398,  1.19211898, -1.19211898, ..., -0.05694238,
#         -0.11737989, -0.03284022],
#        [-0.33072423,  1.19211898, -1.19211898, ..., -0.05694238,
#         -0.11737989, -0.03284022],
#        [ 1.82575941,  1.19211898, -1.19211898, ..., -0.05694238,
#         -0.11737989, -0.03284022],
#        ...,
#        [-0.35181757,  1.19211898, -1.19211898, ..., -0.05694238,
#         -0.11737989, -0.03284022],
#        [-0.01804651, -0.83884244,  0.83884244, ..., -0.05694238,
#         -0.11737989, -0.03284022],
#        [ 0.71029405, -0.83884244,  0.83884244, ..., -0.05694238,
#         -0.11737989, -0.03284022]])

# %%
preprocessor.transform(X_test)
# Out:
# array([[-0.30342697, -0.83884244,  0.83884244, ..., -0.05694238,
#         -0.11737989, -0.03284022],
#        [-0.32948344,  1.19211898, -1.19211898, ..., -0.05694238,
#         -0.11737989, -0.03284022],
#        [-0.34561364, -0.83884244,  0.83884244, ..., -0.05694238,
#         -0.11737989, -0.03284022],
#        ...,
#        [ 2.39776111,  1.19211898, -1.19211898, ..., -0.05694238,
#         -0.11737989, -0.03284022],
#        [ 0.2387959 , -0.83884244,  0.83884244, ..., -0.05694238,
#         -0.11737989, -0.03284022],
#        [-0.23518381,  1.19211898, -1.19211898, ..., -0.05694238,
#         -0.11737989, -0.03284022]])

# %%
preprocessor.get_feature_names_out()    #list of features which will be transformed
# Out:
# array(['num_pipeline__votes', 'cat_pipeline__online_order_No',
#        'cat_pipeline__online_order_Yes', 'cat_pipeline__book_table_No',
#        'cat_pipeline__book_table_Yes', 'cat_pipeline__location_BTM',
#        'cat_pipeline__location_Banashankari',
#        'cat_pipeline__location_Banaswadi',
#        'cat_pipeline__location_Bannerghatta Road',
#        'cat_pipeline__location_Basavanagudi',
#        'cat_pipeline__location_Bellandur',
#        'cat_pipeline__location_Brigade Road',
#        'cat_pipeline__location_Brookefield',
#        'cat_pipeline__location_Church Street',
#        'cat_pipeline__location_Electronic City',
#        'cat_pipeline__location_Frazer Town', 'cat_pipeline__location_HSR',
#        'cat_pipeline__location_Indiranagar',
#        'cat_pipeline__location_JP Nagar',
#        'cat_pipeline__location_Jayanagar',
#        'cat_pipeline__location_Kalyan Nagar',
#        'cat_pipeline__location_Kammanahalli',
#        'cat_pipeline__location_Koramangala 1st Block',
#        'cat_pipeline__location_Koramangala 4th Block',
#        'cat_pipeline__location_Koramangala 5th Block',
#        'cat_pipeline__location_Koramangala 6th Block',
#        'cat_pipeline__location_Koramangala 7th Block',
#        'cat_pipeline__location_Lavelle Road',
#        'cat_pipeline__location_MG Road',
#        'cat_pipeline__location_Malleshwaram',
#        'cat_pipeline__location_Marathahalli',
#        'cat_pipeline__location_New BEL Road',
#        'cat_pipeline__location_Rajajinagar',
#        'cat_pipeline__location_Residency Road',
#        'cat_pipeline__location_Richmond Road',
#        'cat_pipeline__location_Sarjapur Road',
#        'cat_pipeline__location_Shanti Nagar',
#        'cat_pipeline__location_Ulsoor',
#        'cat_pipeline__location_Whitefield',
#        'cat_pipeline__location_others', 'cat_pipeline__rest_type_Bakery',
#        'cat_pipeline__rest_type_Cafe',
#        'cat_pipeline__rest_type_Casual Dining',
#        'cat_pipeline__rest_type_Casual Dining, Bar',
#        'cat_pipeline__rest_type_Delivery',
#        'cat_pipeline__rest_type_Dessert Parlor',
#        'cat_pipeline__rest_type_Quick Bites',
#        'cat_pipeline__rest_type_Takeaway, Delivery',
#        'cat_pipeline__rest_type_others', 'cat_pipeline__cuisines_Bakery',
#        'cat_pipeline__cuisines_Bakery, Desserts',
#        'cat_pipeline__cuisines_Beverages',
#        'cat_pipeline__cuisines_Biryani', 'cat_pipeline__cuisines_Cafe',
#        'cat_pipeline__cuisines_Chinese',
#        'cat_pipeline__cuisines_Chinese, North Indian',
#        'cat_pipeline__cuisines_Desserts',
#        'cat_pipeline__cuisines_Desserts, Ice Cream',
#        'cat_pipeline__cuisines_Fast Food',
#        'cat_pipeline__cuisines_Ice Cream, Desserts',
#        'cat_pipeline__cuisines_Mithai, Street Food',
#        'cat_pipeline__cuisines_North Indian',
#        'cat_pipeline__cuisines_North Indian, Chinese',
#        'cat_pipeline__cuisines_North Indian, Chinese, Biryani',
#        'cat_pipeline__cuisines_North Indian, South Indian',
#        'cat_pipeline__cuisines_North Indian, South Indian, Chinese',
#        'cat_pipeline__cuisines_South Indian',
#        'cat_pipeline__cuisines_South Indian, North Indian',
#        'cat_pipeline__cuisines_South Indian, North Indian, Chinese',
#        'cat_pipeline__cuisines_others', 'cat_pipeline__type_Buffet',
#        'cat_pipeline__type_Cafes', 'cat_pipeline__type_Delivery',
#        'cat_pipeline__type_Desserts', 'cat_pipeline__type_Dine-out',
#        'cat_pipeline__type_Drinks & nightlife',
#        'cat_pipeline__type_Pubs and bars',
#        'cat_pipeline__cost_for_two_people_40.0',
#        'cat_pipeline__cost_for_two_people_50.0',
#        'cat_pipeline__cost_for_two_people_60.0',
#        'cat_pipeline__cost_for_two_people_70.0',
#        'cat_pipeline__cost_for_two_people_80.0',
#        'cat_pipeline__cost_for_two_people_100.0',
#        'cat_pipeline__cost_for_two_people_120.0',
#        'cat_pipeline__cost_for_two_people_130.0',
#        'cat_pipeline__cost_for_two_people_140.0',
#        'cat_pipeline__cost_for_two_people_150.0',
#        'cat_pipeline__cost_for_two_people_160.0',
#        'cat_pipeline__cost_for_two_people_180.0',
#        'cat_pipeline__cost_for_two_people_190.0',
#        'cat_pipeline__cost_for_two_people_199.0',
#        'cat_pipeline__cost_for_two_people_200.0',
#        'cat_pipeline__cost_for_two_people_230.0',
#        'cat_pipeline__cost_for_two_people_240.0',
#        'cat_pipeline__cost_for_two_people_250.0',
#        'cat_pipeline__cost_for_two_people_300.0',
#        'cat_pipeline__cost_for_two_people_330.0',
#        'cat_pipeline__cost_for_two_people_350.0',
#        'cat_pipeline__cost_for_two_people_360.0',
#        'cat_pipeline__cost_for_two_people_400.0',
#        'cat_pipeline__cost_for_two_people_416.63011202591446',
#        'cat_pipeline__cost_for_two_people_450.0',
#        'cat_pipeline__cost_for_two_people_469.0',
#        'cat_pipeline__cost_for_two_people_500.0',
#        'cat_pipeline__cost_for_two_people_550.0',
#        'cat_pipeline__cost_for_two_people_560.0',
#        'cat_pipeline__cost_for_two_people_600.0',
#        'cat_pipeline__cost_for_two_people_650.0',
#        'cat_pipeline__cost_for_two_people_700.0',
#        'cat_pipeline__cost_for_two_people_750.0',
#        'cat_pipeline__cost_for_two_people_800.0',
#        'cat_pipeline__cost_for_two_people_850.0',
#        'cat_pipeline__cost_for_two_people_900.0',
#        'cat_pipeline__cost_for_two_people_950.0'], dtype=object)

# %%
X_train=pd.DataFrame(preprocessor.fit_transform(X_train),columns=preprocessor.get_feature_names_out())
X_test=pd.DataFrame(preprocessor.transform(X_test),columns=preprocessor.get_feature_names_out())

# %%
X_train
# Out:
#        num_pipeline__votes  cat_pipeline__online_order_No  \
# 0                -0.124754                       1.192119
# 1                -0.330724                       1.192119
# 2                 1.825759                       1.192119
# 3                -0.351818                      -0.838842
# 4                -0.351818                      -0.838842
# ...                    ...                            ...
# 36196            -0.344373                      -0.838842
# 36197             0.135811                      -0.838842
# 36198            -0.351818                       1.192119
# 36199            -0.018047                      -0.838842
# 36200             0.710294                      -0.838842
#
#        cat_pipeline__online_order_Yes  cat_pipeline__book_table_No  \
# 0                           -1.192119                     0.376047
# 1                           -1.192119                     0.376047
# 2                           -1.192119                    -2.659243
# 3                            0.838842                     0.376047
# 4                            0.838842                     0.376047
# ...                               ...                          ...
# 36196                        0.838842                     0.376047
# 36197                        0.838842                     0.376047
# 36198                       -1.192119                     0.376047
# 36199                        0.838842                     0.376047
# 36200                        0.838842                    -2.659243
#
#        cat_pipeline__book_table_Yes  cat_pipeline__location_BTM  \
# 0                         -0.376047                    -0.33256
# 1                         -0.376047                    -0.33256
# 2                          2.659243                    -0.33256
# 3                         -0.376047                    -0.33256
# 4                         -0.376047                    -0.33256
# ...                             ...                         ...
# 36196                     -0.376047                    -0.33256
# 36197                     -0.376047                    -0.33256
# 36198                     -0.376047                    -0.33256
# 36199                     -0.376047                    -0.33256
# 36200                      2.659243                    -0.33256
#
#        cat_pipeline__location_Banashankari  cat_pipeline__location_Banaswadi  \
# 0                                 -0.13564                          -0.11543
# 1                                 -0.13564                          -0.11543
# 2                                 -0.13564                          -0.11543
# 3                                 -0.13564                          -0.11543
# 4                                 -0.13564                          -0.11543
# ...                                    ...                               ...
# 36196                             -0.13564                          -0.11543
# 36197                             -0.13564                          -0.11543
# 36198                             -0.13564                          -0.11543
# 36199                             -0.13564                          -0.11543
# 36200                             -0.13564                          -0.11543
#
#        cat_pipeline__location_Bannerghatta Road  \
# 0                                     -0.181133
# 1                                     -0.181133
# 2                                     -0.181133
# 3                                     -0.181133
# 4                                     -0.181133
# ...                                         ...
# 36196                                 -0.181133
# 36197                                 -0.181133
# 36198                                 -0.181133
# 36199                                 -0.181133
# 36200                                 -0.181133
#
#        cat_pipeline__location_Basavanagudi  ...  \
# 0                                -0.114814  ...
# 1                                -0.114814  ...
# 2                                -0.114814  ...
# 3                                -0.114814  ...
# 4                                -0.114814  ...
# ...                                    ...  ...
# 36196                            -0.114814  ...
# 36197                            -0.114814  ...
# 36198                            -0.114814  ...
# 36199                            -0.114814  ...
# 36200                            -0.114814  ...
#
#        cat_pipeline__cost_for_two_people_550.0  \
# 0                                    -0.123402
# 1                                    -0.123402
# 2                                    -0.123402
# 3                                    -0.123402
# 4                                    -0.123402
# ...                                        ...
# 36196                                -0.123402
# 36197                                -0.123402
# 36198                                -0.123402
# 36199                                -0.123402
# 36200                                -0.123402
#
#        cat_pipeline__cost_for_two_people_560.0  \
# 0                                    -0.005256
# 1                                    -0.005256
# 2                                    -0.005256
# 3                                    -0.005256
# 4                                    -0.005256
# ...                                        ...
# 36196                                -0.005256
# 36197                                -0.005256
# 36198                                -0.005256
# 36199                                -0.005256
# 36200                                -0.005256
#
#        cat_pipeline__cost_for_two_people_600.0  \
# 0                                    -0.276785
# 1                                    -0.276785
# 2                                    -0.276785
# 3                                     3.612919
# 4                                    -0.276785
# ...                                        ...
# 36196                                -0.276785
# 36197                                -0.276785
# 36198                                -0.276785
# 36199                                -0.276785
# 36200                                -0.276785
#
#        cat_pipeline__cost_for_two_people_650.0  \
# 0                                    -0.121074
# 1                                    -0.121074
# 2                                    -0.121074
# 3                                    -0.121074
# 4                                    -0.121074
# ...                                        ...
# 36196                                -0.121074
# 36197                                -0.121074
# 36198                                -0.121074
# 36199                                -0.121074
# 36200                                -0.121074
#
#        cat_pipeline__cost_for_two_people_700.0  \
# 0                                    -0.195372
# 1                                    -0.195372
# 2                                    -0.195372
# 3                                    -0.195372
# 4                                    -0.195372
# ...                                        ...
# 36196                                -0.195372
# 36197                                -0.195372
# 36198                                -0.195372
# 36199                                -0.195372
# 36200                                -0.195372
#
#        cat_pipeline__cost_for_two_people_750.0  \
# 0                                    -0.121543
# 1                                    -0.121543
# 2                                    -0.121543
# 3                                    -0.121543
# 4                                    -0.121543
# ...                                        ...
# 36196                                -0.121543
# 36197                                -0.121543
# 36198                                -0.121543
# 36199                                 8.227551
# 36200                                -0.121543
#
#        cat_pipeline__cost_for_two_people_800.0  \
# 0                                    -0.215249
# 1                                    -0.215249
# 2                                    -0.215249
# 3                                    -0.215249
# 4                                    -0.215249
# ...                                        ...
# 36196                                -0.215249
# 36197                                -0.215249
# 36198                                -0.215249
# 36199                                -0.215249
# 36200                                -0.215249
#
#        cat_pipeline__cost_for_two_people_850.0  \
# 0                                    -0.056942
# 1                                    -0.056942
# 2                                    -0.056942
# 3                                    -0.056942
# 4                                    -0.056942
# ...                                        ...
# 36196                                -0.056942
# 36197                                -0.056942
# 36198                                -0.056942
# 36199                                -0.056942
# 36200                                -0.056942
#
#        cat_pipeline__cost_for_two_people_900.0  \
# 0                                     -0.11738
# 1                                     -0.11738
# 2                                     -0.11738
# 3                                     -0.11738
# 4                                     -0.11738
# ...                                        ...
# 36196                                 -0.11738
# 36197                                 -0.11738
# 36198                                 -0.11738
# 36199                                 -0.11738
# 36200                                 -0.11738
#
#        cat_pipeline__cost_for_two_people_950.0
# 0                                     -0.03284
# 1                                     -0.03284
# 2                                     -0.03284
# 3                                     -0.03284
# 4                                     -0.03284
# ...                                        ...
# 36196                                 -0.03284
# 36197                                 -0.03284
# 36198                                 -0.03284
# 36199                                 -0.03284
# 36200                                 -0.03284
#
# [36201 rows x 114 columns]

# %%
X_test
# Out:
#        num_pipeline__votes  cat_pipeline__online_order_No  \
# 0                -0.303427                      -0.838842
# 1                -0.329483                       1.192119
# 2                -0.345614                      -0.838842
# 3                -0.319557                      -0.838842
# 4                 0.352948                       1.192119
# ...                    ...                            ...
# 15511            -0.351818                       1.192119
# 15512            -0.240147                       1.192119
# 15513             2.397761                       1.192119
# 15514             0.238796                      -0.838842
# 15515            -0.235184                       1.192119
#
#        cat_pipeline__online_order_Yes  cat_pipeline__book_table_No  \
# 0                            0.838842                     0.376047
# 1                           -1.192119                     0.376047
# 2                            0.838842                     0.376047
# 3                            0.838842                     0.376047
# 4                           -1.192119                    -2.659243
# ...                               ...                          ...
# 15511                       -1.192119                     0.376047
# 15512                       -1.192119                     0.376047
# 15513                       -1.192119                    -2.659243
# 15514                        0.838842                    -2.659243
# 15515                       -1.192119                     0.376047
#
#        cat_pipeline__book_table_Yes  cat_pipeline__location_BTM  \
# 0                         -0.376047                    3.006973
# 1                         -0.376047                    3.006973
# 2                         -0.376047                   -0.332560
# 3                         -0.376047                   -0.332560
# 4                          2.659243                   -0.332560
# ...                             ...                         ...
# 15511                     -0.376047                   -0.332560
# 15512                     -0.376047                   -0.332560
# 15513                      2.659243                   -0.332560
# 15514                      2.659243                   -0.332560
# 15515                     -0.376047                   -0.332560
#
#        cat_pipeline__location_Banashankari  cat_pipeline__location_Banaswadi  \
# 0                                 -0.13564                          -0.11543
# 1                                 -0.13564                          -0.11543
# 2                                 -0.13564                          -0.11543
# 3                                 -0.13564                          -0.11543
# 4                                 -0.13564                          -0.11543
# ...                                    ...                               ...
# 15511                             -0.13564                          -0.11543
# 15512                             -0.13564                          -0.11543
# 15513                             -0.13564                          -0.11543
# 15514                             -0.13564                          -0.11543
# 15515                             -0.13564                          -0.11543
#
#        cat_pipeline__location_Bannerghatta Road  \
# 0                                     -0.181133
# 1                                     -0.181133
# 2                                     -0.181133
# 3                                     -0.181133
# 4                                     -0.181133
# ...                                         ...
# 15511                                 -0.181133
# 15512                                 -0.181133
# 15513                                 -0.181133
# 15514                                 -0.181133
# 15515                                 -0.181133
#
#        cat_pipeline__location_Basavanagudi  ...  \
# 0                                -0.114814  ...
# 1                                -0.114814  ...
# 2                                -0.114814  ...
# 3                                -0.114814  ...
# 4                                -0.114814  ...
# ...                                    ...  ...
# 15511                            -0.114814  ...
# 15512                            -0.114814  ...
# 15513                            -0.114814  ...
# 15514                            -0.114814  ...
# 15515                            -0.114814  ...
#
#        cat_pipeline__cost_for_two_people_550.0  \
# 0                                    -0.123402
# 1                                    -0.123402
# 2                                    -0.123402
# 3                                    -0.123402
# 4                                    -0.123402
# ...                                        ...
# 15511                                -0.123402
# 15512                                -0.123402
# 15513                                -0.123402
# 15514                                -0.123402
# 15515                                -0.123402
#
#        cat_pipeline__cost_for_two_people_560.0  \
# 0                                    -0.005256
# 1                                    -0.005256
# 2                                    -0.005256
# 3                                    -0.005256
# 4                                    -0.005256
# ...                                        ...
# 15511                                -0.005256
# 15512                                -0.005256
# 15513                                -0.005256
# 15514                                -0.005256
# 15515                                -0.005256
#
#        cat_pipeline__cost_for_two_people_600.0  \
# 0                                    -0.276785
# 1                                    -0.276785
# 2                                    -0.276785
# 3                                    -0.276785
# 4                                    -0.276785
# ...                                        ...
# 15511                                -0.276785
# 15512                                -0.276785
# 15513                                -0.276785
# 15514                                -0.276785
# 15515                                -0.276785
#
#        cat_pipeline__cost_for_two_people_650.0  \
# 0                                    -0.121074
# 1                                    -0.121074
# 2                                    -0.121074
# 3                                    -0.121074
# 4                                    -0.121074
# ...                                        ...
# 15511                                -0.121074
# 15512                                -0.121074
# 15513                                -0.121074
# 15514                                -0.121074
# 15515                                -0.121074
#
#        cat_pipeline__cost_for_two_people_700.0  \
# 0                                    -0.195372
# 1                                    -0.195372
# 2                                    -0.195372
# 3                                    -0.195372
# 4                                    -0.195372
# ...                                        ...
# 15511                                -0.195372
# 15512                                -0.195372
# 15513                                -0.195372
# 15514                                -0.195372
# 15515                                 5.118432
#
#        cat_pipeline__cost_for_two_people_750.0  \
# 0                                    -0.121543
# 1                                    -0.121543
# 2                                    -0.121543
# 3                                    -0.121543
# 4                                    -0.121543
# ...                                        ...
# 15511                                -0.121543
# 15512                                -0.121543
# 15513                                -0.121543
# 15514                                -0.121543
# 15515                                -0.121543
#
#        cat_pipeline__cost_for_two_people_800.0  \
# 0                                    -0.215249
# 1                                    -0.215249
# 2                                    -0.215249
# 3                                    -0.215249
# 4                                    -0.215249
# ...                                        ...
# 15511                                -0.215249
# 15512                                -0.215249
# 15513                                -0.215249
# 15514                                -0.215249
# 15515                                -0.215249
#
#        cat_pipeline__cost_for_two_people_850.0  \
# 0                                    -0.056942
# 1                                    -0.056942
# 2                                    -0.056942
# 3                                    -0.056942
# 4                                    -0.056942
# ...                                        ...
# 15511                                -0.056942
# 15512                                -0.056942
# 15513                                -0.056942
# 15514                                -0.056942
# 15515                                -0.056942
#
#        cat_pipeline__cost_for_two_people_900.0  \
# 0                                     -0.11738
# 1                                     -0.11738
# 2                                     -0.11738
# 3                                     -0.11738
# 4                                     -0.11738
# ...                                        ...
# 15511                                 -0.11738
# 15512                                 -0.11738
# 15513                                 -0.11738
# 15514                                 -0.11738
# 15515                                 -0.11738
#
#        cat_pipeline__cost_for_two_people_950.0
# 0                                     -0.03284
# 1                                     -0.03284
# 2                                     -0.03284
# 3                                     -0.03284
# 4                                     -0.03284
# ...                                        ...
# 15511                                 -0.03284
# 15512                                 -0.03284
# 15513                                 -0.03284
# 15514                                 -0.03284
# 15515                                 -0.03284
#
# [15516 rows x 114 columns]

# %%
## Model Training

from sklearn.linear_model import LinearRegression
from sklearn.tree import DecisionTreeRegressor
from sklearn.ensemble import RandomForestRegressor
from sklearn.neighbors import KNeighborsRegressor 
from sklearn.metrics import r2_score,mean_absolute_error,mean_squared_error

# %%
import numpy as np
def evaluate_model(true, predicted):
    mae = mean_absolute_error(true, predicted)
    mse = mean_squared_error(true, predicted)
    rmse = np.sqrt(mean_squared_error(true, predicted))
    r2_square = r2_score(true, predicted)
    return mae, rmse, r2_square

# %%
## Train multiple models

models={
    'LinearRegression':LinearRegression(),
    'DecisionTreeRegressor':DecisionTreeRegressor(),
    'RandomForestRegressor':RandomForestRegressor(),
    'KNN': KNeighborsRegressor()
    }

# %%
trained_model_list=[]
model_list=[]
r2_list=[]

# %%
list(models)
# Out:
# ['LinearRegression', 'DecisionTreeRegressor', 'RandomForestRegressor', 'KNN']

# %%
for i in range(len(list(models))):
    model=list(models.values())[i]
    print(model)
# Out:
# LinearRegression()
# DecisionTreeRegressor()
# RandomForestRegressor()
# KNeighborsRegressor()

# %%
models.keys()
# Out:
# dict_keys(['LinearRegression', 'DecisionTreeRegressor', 'RandomForestRegressor', 'KNN'])

# %%
models.values()
# Out:
# dict_values([LinearRegression(), DecisionTreeRegressor(), RandomForestRegressor(), KNeighborsRegressor()])

# %%
for i in range(len(list(models))):
    model=list(models.values())[i]
    model.fit(X_train,y_train)

    #Make Predictions
    y_pred=model.predict(X_test)

    #this is a validation(test) score
    mae, rmse, r2_square=evaluate_model(y_test,y_pred)

    print(list(models.keys())[i])
    model_list.append(list(models.keys())[i])

    print('Model Training Performance')
    print("RMSE:",rmse)
    print("MAE:",mae)
    print("R2 score",r2_square*100)

    r2_list.append(r2_square)
    
    print('='*35)
    print('\n')
# Out:
# LinearRegression
# Model Training Performance
# RMSE: 0.3233925282046103
# MAE: 0.24581411307340906
# R2 score 31.873565548281533
# ===================================
#
#
# DecisionTreeRegressor
# Model Training Performance
# RMSE: 0.15437801501098355
# MAE: 0.04478980367343901
# R2 score 84.47517899632211
# ===================================
# c:\FSDS\ML\Restaurant_Rating_Prediction\env\lib\site-packages\sklearn\base.py:1152: DataConversionWarning: A column-vector y was passed when a 1d array was expected. Please change the shape of y to (n_samples,), for example using ravel().
#   return fit_method(estimator, *args, **kwargs)
# RandomForestRegressor
# Model Training Performance
# RMSE: 0.13207740810298366
# MAE: 0.05663679691775938
# R2 score 88.6364828414279
# ===================================
#
#
# KNN
# Model Training Performance
# RMSE: 0.25977128115620773
# MAE: 0.1675664389607294
# R2 score 56.04199550068498
# ===================================

# %%
model_list
# Out:
# ['LinearRegression', 'DecisionTreeRegressor', 'RandomForestRegressor', 'KNN']

# %%
r2_list
# Out:
# [0.31873565548281535,
#  0.8447517899632211,
#  0.8863648284142791,
#  0.5604199550068498]
